# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML
#pd.options.display.max_colwidth = 200
df = pd.read_csv('movies_complete.csv', parse_dates=['release_date'])

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
df.loc[:,['id', 'title', 'revenue_musd']].sort_values('revenue_musd', ascending=False).head(5)
# Out:
#            id                         title  revenue_musd
# 14448   19995                        Avatar   2787.965087
# 26265  140607  Star Wars: The Force Awakens   2068.223624
# 1620      597                       Titanic   1845.034188
# 17669   24428                  The Avengers   1519.557910
# 24812  135397                Jurassic World   1513.528810

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
df.loc[:,['id', 'title', 'budget_musd']].sort_values('budget_musd', ascending=False).head(5)
# Out:
#           id                                        title  budget_musd
# 16986   1865  Pirates of the Caribbean: On Stranger Tides        380.0
# 11743    285     Pirates of the Caribbean: At World's End        300.0
# 26268  99861                      Avengers: Age of Ultron        280.0
# 10985   1452                             Superman Returns        270.0
# 18517  49529                                  John Carter        260.0

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
df['profit_musd'] = df['revenue_musd'] - df['budget_musd']
df.loc[:,['id', 'title', 'profit_musd']].sort_values('profit_musd', ascending=False).head(5)
# Out:
#            id                         title  profit_musd
# 14448   19995                        Avatar  2550.965087
# 26265  140607  Star Wars: The Force Awakens  1823.223624
# 1620      597                       Titanic  1645.034188
# 24812  135397                Jurassic World  1363.528810
# 28501  168259                     Furious 7  1316.249360

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
df.loc[:,['id', 'title', 'profit_musd']].sort_values('profit_musd', ascending=True).head(5)
# Out:
#            id                                        title  profit_musd
# 20959   57201                              The Lone Ranger  -165.710090
# 7164    10733                                    The Alamo  -119.180039
# 16659   50321                              Mars Needs Moms  -111.007242
# 43611  339964  Valerian and the City of a Thousand Planets  -107.447384
# 2684     1911                             The 13th Warrior   -98.301101

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
df['roi'] = df['revenue_musd'] / df['budget_musd']
df[df['budget_musd'] >= 10].loc[:,['id', 'title', 'roi']].sort_values('roi', ascending=False).head(5)
# Out:
#           id                       title        roi
# 1055     601  E.T. the Extra-Terrestrial  75.520507
# 255       11                   Star Wars  70.490728
# 588      114                Pretty Woman  33.071429
# 18300  77338            The Intouchables  32.806221
# 1144    1891     The Empire Strikes Back  29.911111

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
df[df['budget_musd'] >= 10].loc[:,['id', 'title', 'roi']].sort_values('roi', ascending=True).head(5)
# Out:
#           id            title           roi
# 6955   14844  Chasing Liberty  5.217391e-07
# 8041   18475      The Cookout  7.500000e-07
# 17381  33927         Deadfall  1.800000e-06
# 6678   10944       In the Cut  1.916667e-06
# 20015  98339    The Samaritan  2.100833e-04

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
df.loc[:,['id', 'title', 'vote_count']].sort_values('vote_count', ascending=False).head(5)
# Out:
#            id            title  vote_count
# 15368   27205        Inception     14075.0
# 12396     155  The Dark Knight     12269.0
# 14448   19995           Avatar     12114.0
# 17669   24428     The Avengers     12000.0
# 26272  293660         Deadpool     11444.0

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
df.loc[:,['id', 'title', 'vote_average']].sort_values('vote_average', ascending=False).head(5)
# Out:
#            id                                       title  vote_average
# 36996  162611  Portrait of a Young Man in Three Movements          10.0
# 33891  143980                         Brave Revolutionary          10.0
# 1615    64562                    Other Voices Other Rooms          10.0
# 35505  211139                          The Lion of Thebes          10.0
# 25882  287299         Katt Williams: Priceless: Afterlife          10.0

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
df.loc[:,['id', 'title', 'vote_average']].sort_values('vote_average', ascending=True).head(5)
# Out:
#            id                                        title  vote_average
# 24522  154515                          Dance, Fools, Dance           0.0
# 37762   93734  .hack Liminality: In the Case of Mai Minase           0.0
# 26403   66963                              Lucrezia Borgia           0.0
# 12189  111744                                  Joe and Max           0.0
# 20450  281583                               The Substitute           0.0

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
df.loc[:,['id', 'title', 'popularity']].sort_values('popularity', ascending=False).head(5)
# Out:
#            id                 title  popularity
# 30330  211672               Minions  547.488298
# 32927  297762          Wonder Woman  294.337037
# 41556  321612  Beauty and the Beast  287.253654
# 42940  339403           Baby Driver  228.032744
# 24187  177572            Big Hero 6  213.849907

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
mask1a = df.apply(lambda row: 'Science Fiction' in str(row['genres']).split('|') and 'Action' in str(row['genres']).split('|'), axis=1)
mask1b = df.apply(lambda row: 'Bruce Willis' in str(row['cast']).split('|'), axis=1)
search1 = df[mask1a & mask1b].loc[:, ['poster_path', 'title', 'vote_average']].sort_values('vote_average', ascending=False)

mask2a = df.apply(lambda row: 'Uma Thurman' in str(row['cast']).split('|'), axis=1)
mask2b = df['director']=='Quentin Tarantino'
search2 = df[mask2a & mask2b].loc[:, ['poster_path', 'title', 'runtime']].sort_values('runtime', ascending=True)

mask3a = df.apply(lambda row: row['release_date'] >= pd.to_datetime('2010') and row['release_date'] <= pd.to_datetime('2015'), axis=1)
mask3b = df.apply(lambda row: 'Pixar Animation Studios' in str(row['production_companies']).split('|'), axis=1)
search3 = df[mask3a & mask3b].loc[:, ['poster_path', 'title', 'revenue_musd']].sort_values('revenue_musd', ascending=False)

mask4a = df['genres'].str.contains('Thriller') | df['genres'].str.contains('Action')
mask4b = df['original_language'] == 'en'
mask4c = df['vote_average'] >= 7.5
search4 = df[mask4a & mask4b & mask4c].loc[:, ['poster_path', 'title', 'vote_average', 'release_date']].sort_values('release_date', ascending=False)

# %%
HTML(search1.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>title</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1448</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>The Fifth Element</td>
#       <td>7.3</td>
#     </tr>
#     <tr>
#       <th>19218</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>Looper</td>
#       <td>6.6</td>
#     </tr>
#     <tr>
#       <th>1786</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>Armageddon</td>
#       <td>6.5</td>
#     </tr>
#     <tr>
#       <th>14135</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v3Z0Hbl0oe57njrrIPh0fJPFoo.jpg' style='height:100px;'></td>
#       <td>Surrogates</td>
#       <td>5.9</td>
#     </tr>
#     <tr>
#       <th>20333</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3rWIZMzTKcCtV0eHJ70Z4Ru659f.jpg' style='height:100px;'></td>
#       <td>G.I. Joe: Retaliation</td>
#       <td>5.4</td>
#     </tr>
#     <tr>
#       <th>27619</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//nPqNoQ55RIrmmo9mpqg1jE3ENza.jpg' style='height:100px;'></td>
#       <td>Vice</td>
#       <td>4.1</td>
#     </tr>
#   </tbody>
# </table>

# %%
HTML(search2.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>title</th>
#       <th>runtime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6667</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>Kill Bill: Vol. 1</td>
#       <td>111.0</td>
#     </tr>
#     <tr>
#       <th>7208</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>Kill Bill: Vol. 2</td>
#       <td>136.0</td>
#     </tr>
#     <tr>
#       <th>291</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>Pulp Fiction</td>
#       <td>154.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
HTML(search3.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>title</th>
#       <th>revenue_musd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15236</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>Toy Story 3</td>
#       <td>1066.969703</td>
#     </tr>
#     <tr>
#       <th>20888</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>Monsters University</td>
#       <td>743.559607</td>
#     </tr>
#     <tr>
#       <th>17220</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//okIz1HyxeVOMzYwwHUjH2pHi74I.jpg' style='height:100px;'></td>
#       <td>Cars 2</td>
#       <td>559.852396</td>
#     </tr>
#     <tr>
#       <th>18900</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8l0pzWBrStFtbZiqeu0cGhxGKkT.jpg' style='height:100px;'></td>
#       <td>Brave</td>
#       <td>538.983207</td>
#     </tr>
#     <tr>
#       <th>16392</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eQ1QUZfblOrusXVfbzzCuUaM7ix.jpg' style='height:100px;'></td>
#       <td>Day & Night</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>21694</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iSWV7ra8HJ3gYnZFMMrPe8CBbrv.jpg' style='height:100px;'></td>
#       <td>The Blue Umbrella</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>21697</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aNDrMDZYmcoMlJa6K3VicYeAgt1.jpg' style='height:100px;'></td>
#       <td>Toy Story of Terror!</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>22489</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iS6DB1hIRJHQPs9wWXvIzdnp7oD.jpg' style='height:100px;'></td>
#       <td>La luna</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>24252</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tByW10AkjWG0DtZwN2E2trT88DD.jpg' style='height:100px;'></td>
#       <td>Hawaiian Vacation</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>24254</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//z096FtMoUZxf9kqzSj39YE6psuD.jpg' style='height:100px;'></td>
#       <td>Small Fry</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>25515</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ylj9TnXrTgiETysgBoSb8UQwEUc.jpg' style='height:100px;'></td>
#       <td>Partysaurus Rex</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>25516</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8FKR6880g0JRiblbTQEijGlq3Qj.jpg' style='height:100px;'></td>
#       <td>The Legend of Mor'du</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>25517</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jqQPN3X3aV5VmpTiEEASt36nlfi.jpg' style='height:100px;'></td>
#       <td>Toy Story That Time Forgot</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>40259</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jDwglSvFNBfWJNiyxD41CUcUic1.jpg' style='height:100px;'></td>
#       <td>Air Mater</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %%
HTML(search4.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>title</th>
#       <th>vote_average</th>
#       <th>release_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>44490</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>Descendants 2</td>
#       <td>7.5</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>43941</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>Dunkirk</td>
#       <td>7.5</td>
#       <td>2017-07-19</td>
#     </tr>
#     <tr>
#       <th>42624</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//suLFg4UjvM5BoDipg2Wu3gZ802T.jpg' style='height:100px;'></td>
#       <td>The Book of Henry</td>
#       <td>7.6</td>
#       <td>2017-06-16</td>
#     </tr>
#     <tr>
#       <th>26273</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg' style='height:100px;'></td>
#       <td>Guardians of the Galaxy Vol. 2</td>
#       <td>7.6</td>
#       <td>2017-04-19</td>
#     </tr>
#     <tr>
#       <th>43467</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//p4StxfnkrawbbXt3JcJlB4Q8DCm.jpg' style='height:100px;'></td>
#       <td>Revengeance</td>
#       <td>8.0</td>
#       <td>2017-04-05</td>
#     </tr>
#     <tr>
#       <th>44431</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//91uJTOxrbiy9g0Y9uatCaXp5kCd.jpg' style='height:100px;'></td>
#       <td>First Round Down</td>
#       <td>10.0</td>
#       <td>2017-03-04</td>
#     </tr>
#     <tr>
#       <th>41506</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fnbjcRDYn6YviCcePDnGdyAkYsB.jpg' style='height:100px;'></td>
#       <td>Logan</td>
#       <td>7.6</td>
#       <td>2017-02-28</td>
#     </tr>
#     <tr>
#       <th>42877</th>
#       <td>NaN</td>
#       <td>Tomato Red</td>
#       <td>8.0</td>
#       <td>2017-02-24</td>
#     </tr>
#     <tr>
#       <th>44447</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ayp1nDEZolwb3eLkgYjHxQydiV1.jpg' style='height:100px;'></td>
#       <td>Zero 3</td>
#       <td>8.7</td>
#       <td>2017-01-27</td>
#     </tr>
#     <tr>
#       <th>41622</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bnozdP26JtPiz7z1AblVnwd4BqG.jpg' style='height:100px;'></td>
#       <td>The River Thief</td>
#       <td>9.3</td>
#       <td>2016-10-14</td>
#     </tr>
#     <tr>
#       <th>40525</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//55yQMgLwJDyEom2Kose80JjTlDt.jpg' style='height:100px;'></td>
#       <td>The Thinning</td>
#       <td>7.6</td>
#       <td>2016-10-12</td>
#     </tr>
#     <tr>
#       <th>42655</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//krwEgVt7tPzhl2RsCbjgkBX6948.jpg' style='height:100px;'></td>
#       <td>Only For One Night</td>
#       <td>8.0</td>
#       <td>2016-10-01</td>
#     </tr>
#     <tr>
#       <th>42871</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//pZFWPuch66T30qa6xIxHZvPYjdg.jpg' style='height:100px;'></td>
#       <td>Bad Girl</td>
#       <td>8.0</td>
#       <td>2016-08-11</td>
#     </tr>
#     <tr>
#       <th>39108</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//r5wkDzVPqoho8Iy4XOvYeFGI31P.jpg' style='height:100px;'></td>
#       <td>American Hostage</td>
#       <td>10.0</td>
#       <td>2016-03-25</td>
#     </tr>
#     <tr>
#       <th>37677</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5EJGeeuPy19EGDy8HErpbHba0yq.jpg' style='height:100px;'></td>
#       <td>11.22.63</td>
#       <td>8.0</td>
#       <td>2016-02-15</td>
#     </tr>
#     <tr>
#       <th>44284</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eQRxYMuO79opEzvSRwLL7w3W6Lm.jpg' style='height:100px;'></td>
#       <td>Junction 48</td>
#       <td>8.0</td>
#       <td>2016-02-13</td>
#     </tr>
#     <tr>
#       <th>26265</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>Star Wars: The Force Awakens</td>
#       <td>7.5</td>
#       <td>2015-12-15</td>
#     </tr>
#     <tr>
#       <th>42581</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//Ef9ZvB7p0BWJwEup7KE6x96NDw.jpg' style='height:100px;'></td>
#       <td>London Spy</td>
#       <td>8.8</td>
#       <td>2015-11-09</td>
#     </tr>
#     <tr>
#       <th>32618</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//28Vnvn1WI1wJtP1kDqeRCZ1GdYm.jpg' style='height:100px;'></td>
#       <td>Spotlight</td>
#       <td>7.8</td>
#       <td>2015-11-06</td>
#     </tr>
#     <tr>
#       <th>31737</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//pCURNjeomWbMSdiP64gj8NVVHTQ.jpg' style='height:100px;'></td>
#       <td>Room</td>
#       <td>8.1</td>
#       <td>2015-10-16</td>
#     </tr>
#     <tr>
#       <th>35838</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//k5uLNLfmX5aUVm9uiYpAA1uj4BQ.jpg' style='height:100px;'></td>
#       <td>The Fear of 13</td>
#       <td>8.0</td>
#       <td>2015-10-15</td>
#     </tr>
#     <tr>
#       <th>34335</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//nUQDNzBp8IvqkvLYdCYsoQhaDaS.jpg' style='height:100px;'></td>
#       <td>3 ½ Minutes, 10 Bullets</td>
#       <td>7.8</td>
#       <td>2015-10-02</td>
#     </tr>
#     <tr>
#       <th>33035</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2e0zkY38Qykc69C4eK7uCMOIHfM.jpg' style='height:100px;'></td>
#       <td>An Inspector Calls</td>
#       <td>7.6</td>
#       <td>2015-09-13</td>
#     </tr>
#     <tr>
#       <th>40248</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//cfNIGPbiq4nyxPwxFTKY2abxqvv.jpg' style='height:100px;'></td>
#       <td>Interruption</td>
#       <td>7.5</td>
#       <td>2015-09-08</td>
#     </tr>
#     <tr>
#       <th>37991</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3VZYD81ZTrufSVkzsYPsezePY6K.jpg' style='height:100px;'></td>
#       <td>Queen of Carthage</td>
#       <td>7.5</td>
#       <td>2015-09-01</td>
#     </tr>
#     <tr>
#       <th>29709</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//nbWY6797LUxXRSYwamHp8V0X4dA.jpg' style='height:100px;'></td>
#       <td>Kung Fury</td>
#       <td>7.6</td>
#       <td>2015-05-22</td>
#     </tr>
#     <tr>
#       <th>25257</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//r6q9wZK5a2K51KFj4LWVID6Ja1r.jpg' style='height:100px;'></td>
#       <td>Kingsman: The Secret Service</td>
#       <td>7.6</td>
#       <td>2015-01-29</td>
#     </tr>
#     <tr>
#       <th>43940</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//he609rnU3tiwBjRklKNa4n2jQSd.jpg' style='height:100px;'></td>
#       <td>Black Mirror: White Christmas</td>
#       <td>8.3</td>
#       <td>2014-12-16</td>
#     </tr>
#     <tr>
#       <th>32447</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wRh3OeUmzouuqkBymWh4WSuWFkL.jpg' style='height:100px;'></td>
#       <td>Zid</td>
#       <td>7.5</td>
#       <td>2014-11-28</td>
#     </tr>
#     <tr>
#       <th>24588</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ntZGfHt4d73A9fDD4KUN4nbDQlq.jpg' style='height:100px;'></td>
#       <td>The Imitation Game</td>
#       <td>8.0</td>
#       <td>2014-11-14</td>
#     </tr>
#     <tr>
#       <th>24187</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//xozrGME58olN1xBhtxmjpOoY0jH.jpg' style='height:100px;'></td>
#       <td>Big Hero 6</td>
#       <td>7.8</td>
#       <td>2014-10-24</td>
#     </tr>
#     <tr>
#       <th>24177</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gYPIRu0jX2CGYdeO422cq3N78ju.jpg' style='height:100px;'></td>
#       <td>Nightcrawler</td>
#       <td>7.6</td>
#       <td>2014-10-23</td>
#     </tr>
#     <tr>
#       <th>41831</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bwP6r44YzP58Dxdiupj5NVWgZgT.jpg' style='height:100px;'></td>
#       <td>October 1</td>
#       <td>8.0</td>
#       <td>2014-10-01</td>
#     </tr>
#     <tr>
#       <th>23419</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tQf4DUygWo64AOuqgk4jEDCE3Ws.jpg' style='height:100px;'></td>
#       <td>Gone Girl</td>
#       <td>7.9</td>
#       <td>2014-10-01</td>
#     </tr>
#     <tr>
#       <th>33824</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9bF51qjrtnWGdOam74hRIOm4LRF.jpg' sty

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df['Franchise'] = df['belongs_to_collection'].notna()
gbo = df.groupby('Franchise')
gbo['revenue_musd'].mean()
# Out:
# Franchise
# False     44.742814
# True     165.708193
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
gbo['roi'].median()
# Out:
# Franchise
# False    1.619699
# True     3.709195
# Name: roi, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
gbo['budget_musd'].mean()
# Out:
# Franchise
# False    18.047741
# True     38.319847
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
gbo['popularity'].mean()
# Out:
# Franchise
# False    2.592726
# True     6.245051
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
gbo['vote_average'].mean()
# Out:
# Franchise
# False    6.008787
# True     5.956806
# Name: vote_average, dtype: float64

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
gbo2 = df[df['Franchise']].groupby('belongs_to_collection')
print('Number of Movies: ')
print(gbo2['id'].count().sort_values(ascending=False).head(5))
print('---------------------------------')
print('Mean Budget: ')
print(gbo2.agg({'budget_musd': ['sum', 'mean']}).sort_values(by=('budget_musd', 'mean'), ascending=False).head(5))
print('---------------------------------')
print('Mean Revenue: ')
print(gbo2.agg({'revenue_musd': ['sum', 'mean']}).nlargest(5, ('revenue_musd', 'mean')))
print('---------------------------------')
print('Mean Rating: ')
print(gbo2['vote_average'].mean().sort_values(ascending=False).head(5))
print('---------------------------------')
# Out:
# Number of Movies:
# belongs_to_collection
# The Bowery Boys                  29
# Totò Collection                  27
# James Bond Collection            26
# Zatôichi: The Blind Swordsman    26
# The Carry On Collection          25
# Name: id, dtype: int64
# ---------------------------------
# Mean Budget:
#                                     budget_musd
#                                             sum   mean
# belongs_to_collection
# Tangled Collection                        260.0  260.0
# The Avengers Collection                   500.0  250.0
# Pirates of the Caribbean Collection      1250.0  250.0
# The Hobbit Collection                     750.0  250.0
# Man of Steel Collection                   475.0  237.5
# ---------------------------------
# Mean Revenue:
#                         revenue_musd
#                                  sum         mean
# belongs_to_collection
# Avatar Collection        2787.965087  2787.965087
# The Avengers Collection  2924.961604  1462.480802
# Frozen Collection        1274.219009  1274.219009
# Finding Nemo Collection  1968.906425   984.453213
# The Hobbit Collection    2935.523356   978.507785
# ---------------------------------
# Mean Rating:
# belongs_to_collection
# Argo Collection                        9.3
# Kenji Misumi's Trilogy of the Sword    9.0
# Dreileben                              9.0
# Bloodfight                             9.0
# Алиса в стране чудес (Коллекция)       8.7
# Name: vote_average, dtype: float64
# ---------------------------------

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
director = df.groupby('director').agg({'title': 'count', 'revenue_musd': 'sum', 'vote_average': 'mean'})
print('Number of Movies: ')
print(director.nlargest(5, 'title'))
print('------------------------------------------------------------------')
print('Total Revenue: ')
print(director.nlargest(5, 'revenue_musd'))
print('------------------------------------------------------------------')
print('Mean Rating: ')
print(director.nlargest(5, 'vote_average'))
print('------------------------------------------------------------------')
# Out:
# Number of Movies:
#                   title  revenue_musd  vote_average
# director
# John Ford            66     85.170757      6.381818
# Michael Curtiz       65     37.817500      5.998246
# Werner Herzog        54     24.572580      6.805556
# Alfred Hitchcock     53    250.107584      6.639623
# Georges Méliès       49      0.000000      5.934694
# ------------------------------------------------------------------
# Total Revenue:
#                   title  revenue_musd  vote_average
# director
# Steven Spielberg     33   9256.621422      6.893939
# Peter Jackson        13   6528.244659      7.138462
# Michael Bay          13   6437.466781      6.392308
# James Cameron        11   5900.610310      6.927273
# David Yates           9   5334.563196      6.700000
# ------------------------------------------------------------------
# Mean Rating:
#                title  revenue_musd  vote_average
# director
# A.W. Vidmer        1           0.0          10.0
# Amy Schatz         1           0.0          10.0
# Ana Poliak         1           0.0          10.0
# Andrew Bowser      1           0.0          10.0
# Andrew Napier      1           0.0          10.0
# ------------------------------------------------------------------

# %% [markdown]
# ## Most Successful Actors

# %%
dfIndexed = df.set_index('id')

# %%
actors = dfIndexed['cast'].str.split('|', expand=True).stack().reset_index(1, drop=True).to_frame().rename(columns={0: 'Actor'})
actors = actors.merge(dfIndexed, how='left', left_index=True, right_index=True)

# %%
actorsGBO = actors.groupby('Actor').agg({'title': 'count', 'revenue_musd': ['sum', 'mean'], 'vote_average': 'mean', 'popularity': 'mean'})

# %%
actorsGBO.nlargest(10, ('title', 'count'))
# Out:
#                   title  revenue_musd             vote_average popularity
#                   count           sum        mean         mean       mean
# Actor
# Bess Flowers        240    368.913259   14.756530     6.184186   2.030528
# Christopher Lee     148   9417.047887  324.725789     5.910204   4.749606
# John Wayne          125    236.094000   11.242571     5.712097   3.092939
# Samuel L. Jackson   122  17109.620672  213.870258     6.266116  11.703945
# Michael Caine       110   8053.404838  191.747734     6.269444   8.265272
# Gérard Depardieu    109   1247.608953   95.969919     6.053211   3.703836
# John Carradine      109    255.839586   19.679968     5.546667   2.434950
# Donald Sutherland   108   5390.766679  138.224787     6.233962   7.003230
# Jackie Chan         108   4699.185933  146.849560     6.275701   5.862638
# Frank Welker        107  13044.152470  326.103812     6.310377   9.571404

# %%
actorsGBO.nlargest(10, ('revenue_musd', 'sum'))
# Out:
#                   title  revenue_musd             vote_average popularity
#                   count           sum        mean         mean       mean
# Actor
# Stan Lee             48  19414.957555  647.165252     6.513043  29.936175
# Samuel L. Jackson   122  17109.620672  213.870258     6.266116  11.703945
# Warwick Davis        34  13256.032188  662.801609     6.294118  13.088614
# Frank Welker        107  13044.152470  326.103812     6.310377   9.571404
# John Ratzenberger    46  12596.126073  449.861645     6.484444  10.959477
# Jess Harnell         35  12234.608163  611.730408     6.435294  10.919015
# Hugo Weaving         40  11027.578473  459.482436     6.473684  10.967890
# Ian McKellen         44  11015.592318  478.938796     6.353488  15.447180
# Johnny Depp          69  10653.760641  217.423687     6.440580  12.378196
# Alan Rickman         45  10612.625348  353.754178     6.715556  10.399285

# %%
actorsGBO[actorsGBO.loc[:, ('title', 'count')] > 10].nlargest(10, ('revenue_musd', 'mean'))
# Out:
#                  title revenue_musd              vote_average popularity
#                  count          sum         mean         mean       mean
# Actor
# Gloria Stuart       18  1845.034188  1845.034188     6.368750   3.477432
# Keith Richards      23  2967.713802   989.237934     6.463636   5.032988
# James Cameron       12  1862.075059   931.037530     7.063636   4.691718
# Matthew Lewis       11  7915.312500   879.479167     7.372727  23.097479
# Luke de Woolfson    11  1720.671036   860.335518     5.718182   8.767206
# Yuri Lowenthal      17  1708.162716   854.081358     6.188235  19.884649
# Dominic Monaghan    11  3289.607607   822.401902     6.045455  10.621675
# Peter Mayhew        11  4820.721631   803.453605     6.700000  12.303552
# Victoria De Mare    12   783.112979   783.112979     5.058333  17.606919
# Alex Zahara         17   769.653595   769.653595     5.958824   5.087243

# %%
actorsGBO[actorsGBO.loc[:, ('title', 'count')] > 10].nlargest(10, ('vote_average', 'mean'))
# Out:
#                    title revenue_musd             vote_average popularity
#                    count          sum        mean         mean       mean
# Actor
# David Attenborough    11     0.000000         NaN     8.270000   2.147383
# Yo Oizumi             13   511.210189  102.242038     7.723077   7.512642
# Şener Şen             16    11.074013    3.691338     7.693333   0.912166
# Akira Tani            12     0.327081    0.163541     7.654545   5.041536
# Daisuke Katô          19     0.423649    0.141216     7.611111   3.428240
# Adile Naşit           15     0.912800    0.456400     7.530769   0.578235
# Haruko Sugimura       19     0.000000         NaN     7.526316   2.155955
# Isao Kimura           11     0.327081    0.163541     7.490000   4.129724
# Mitsuko Yoshikawa     12     0.000000         NaN     7.481818   0.437893
# Yûnosuke Itô          12     0.055240    0.055240     7.472727   2.887282

# %%
actorsGBO[actorsGBO.loc[:, ('title', 'count')] > 10].nlargest(10, ('popularity', 'mean'))
# Out:
#                   title revenue_musd             vote_average popularity
#                   count          sum        mean         mean       mean
# Actor
# Katy Mixon           12  1519.572457  151.957246     5.841667  51.974337
# Terry Notary         11  6947.211370  694.721137     6.472727  51.575849
# Mark Smith           11  2195.523957  243.947106     6.545455  40.076962
# Jon Hamm             25  3449.345393  191.630300     6.328000  39.417351
# Gal Gadot            11  5449.532840  495.412076     6.327273  37.385856
# Ava Acres            21  6272.358330  482.489102     5.985714  36.260864
# Emma Watson          19  9639.203121  535.511284     6.768421  35.965301
# Keith Jardine        11  1062.491947  212.498389     5.963636  32.003903
# Karen Gillan         12  1834.673013  305.778836     6.783333  31.384562
# Wilbur Fitzgerald    12  1539.757207  139.977928     6.525000  31.234321
