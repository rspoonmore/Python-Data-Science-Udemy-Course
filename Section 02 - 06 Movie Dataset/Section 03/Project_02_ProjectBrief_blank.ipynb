# %% [markdown]
# # Project 2: Data Import - Working with Web APIs and JSON (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 2 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Importing Data from JSON files

# %% [markdown]
# 1. __Import__ the json files __blockbusters.json__, __blockbusters2.json__, __blockbusters3.json__ and load the datasets into Pandas DataFrames.

# %%
import pandas as pd
import json
import requests

bb = pd.read_json('blockbusters.json')
bb2 = pd.read_json('blockbusters2.json', orient='records')
bb3 = pd.read_json('blockbusters3.json', orient='split')

#genreDF = pd.json_normalize(data=bb, sep="_", record_path='genres', meta=['title', 'id'], record_prefix='genre')

bb.head()
bb2.head()
bb3.head()
# Out:
#                           title      id     revenue  \
# 0             Avengers: Endgame  299534  2797800564
# 1                        Avatar   19995  2787965087
# 2  Star Wars: The Force Awakens  140607  2068223624
# 3        Avengers: Infinity War  299536  2046239637
# 4                       Titanic     597  1845034188
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                belongs_to_collection  runtime
# 0  {'id': 86311, 'name': 'The Avengers Collection...      181
# 1  {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2  {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3  {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                               None      194

# %% [markdown]
# ## Working with APIs and JSON (Part 1)

# %% [markdown]
# 2. __Create an account__ on https://www.themoviedb.org/

# %% [markdown]
# 3. Get your personal __API Key__

# %% [markdown]
# 4. __API-Request__ (movie module): Load all available information for the movie with __movie id = 140607__ into a Pandas DataFrame. <br> See https://developers.themoviedb.org/3/movies/get-movie-details for more information

# %%
apiKey = '6d70064d319ce27ddb6f38e4856eb669'
movieID = 140607
url = 'https://api.themoviedb.org/3/movie/%s?api_key=%s&language=en-US' % (movieID, apiKey)

req = requests.get(url)
data = req.json()
df = pd.Series(data).to_frame()
pd.json_normalize(data, sep='_')

pd.json_normalize(data, record_path='production_companies', meta='title')
# Out:
#       id                         logo_path            name origin_country  \
# 0      1  /o86DbpburjxrqAzEDhXZcyE8pDb.png  Lucasfilm Ltd.             US
# 1  11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png       Bad Robot             US
#
#                           title
# 0  Star Wars: The Force Awakens
# 1  Star Wars: The Force Awakens

# %% [markdown]
# ## Working with APIs and JSON (Part 2)

# %% [markdown]
# 5. __API-Request__ (discover module): Load all movies with __release date between 2020-01-01 and 2020-02-29__ into a Pandas DataFrame. <br>
# See https://www.themoviedb.org/documentation/api/discover and https://developers.themoviedb.org/3/discover/movie-discover for more information.

# %%
discoverAPIBase = 'https://api.themoviedb.org/3/discover/movie?api_key=%s' % apiKey
startDate = '2020-01-01'
endDate = '2020-02-29'
query1 = '&primary_release_date.gte=%s&primary_release_date.lte=%s' % (startDate, endDate)

req = requests.get(discoverAPIBase+query1)
data = req.json()

pd.DataFrame(data['results'])
# Out:
#     adult                     backdrop_path                    genre_ids  \
# 0   False  /jiqD14fg7UTZOT6qgvzTmfRYpWI.jpg                     [28, 80]
# 1   False  /3N316jUSdhvPyYTW29G4v9ebbcS.jpg                 [53, 28, 80]
# 2   False  /1umKVgbjFG5Cho5ZKTpcvRFJjuJ.jpg                 [35, 53, 80]
# 3   False  /6mKAKhj8POVGqV1GsroS5mGIUe9.jpg                 [14, 28, 12]
# 4   False  /gGwA6YErMjiROavfGyxdciQnlTA.jpg                     [18, 53]
# 5   False  /5VKquU8PNujrxLmsYGHf2TCRNFQ.jpg  [878, 28, 12, 9648, 36, 14]
# 6   False  /ww7eC3BqSbFsyE5H5qMde8WkxJ2.jpg            [28, 27, 878, 53]
# 7   False  /dT05ycGuf4h1uYYAJttxTFKkfBQ.jpg                  [10752, 18]
# 8   False  /4br4B8C0SRIYcKHUgoaOlGo50MU.jpg                         [27]
# 9   False  /lsgYcIbcoQeDZXsHYMOnkvk3sn0.jpg                     [18, 53]
# 10  False  /p6ExERRwodksg0fFKzCjmNCR6Hw.jpg                         [53]
# 11  False  /xRKwiUHGnsZGxZaO6OIKqpzJjPa.jpg                     [28, 53]
# 12  False  /sCtJkYwBrJm8mygRrDGyluf1gSV.jpg                [27, 878, 53]
# 13  False  /ySHlkHDbXztjdjRJ0pZN7FXRnaW.jpg             [16, 12, 28, 14]
# 14  False  /a8ppJJIQmEJcLSFfhxupc4aT4KW.jpg                 [18, 28, 53]
# 15  False  /2kLxuulkqHJHzTLveWGHYjVSHDo.jpg                 [28, 35, 80]
# 16  False  /stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg         [28, 878, 35, 10751]
# 17  False  /aBvw8qYDMmbyU4ttzWSfiTxeICG.jpg                         [35]
# 18  False  /dyvN0x7kjfadYGDszWi18llr1ZY.jpg                  [35, 10749]
# 19  False  /prNSFGKGjtc2lYEr8zjDastCeEg.jpg                  [35, 10749]
#
#         id original_language  \
# 0   495764                en
# 1    38700                en
# 2   609242                es
# 3   666750                en
# 4   596247                es
# 5   582306                en
# 6   443791                en
# 7   662334                es
# 8   575088                ru
# 9   505225                en
# 10  531299                en
# 11  466622                en
# 12  736509                en
# 13  631132                ja
# 14  571785                ko
# 15  591237                en
# 16  454626                en
# 17  557940                es
# 18  623926                es
# 19  552687                ja
#
#                                        original_title  \
# 0   Birds of Prey (and the Fantabulous Emancipatio...
# 1                                   Bad Boys for Life
# 2                                   El robo del siglo
# 3                              Dragonheart: Vengeance
# 4                                       Pacto de fuga
# 5                                    Assassin 33 A.D.
# 6                                          Underwater
# 7                                               Chaco
# 8                            Яга. Кошмар тёмного леса
# 9                            The Last Thing He Wanted
# 10                                         Kill Chain
# 11                                 The Rhythm Section
# 12                                          Intersect
# 13                         ゴブリンスレイヤー -GOBLIN'S CROWN-
# 14                                             사냥의 시간
# 15                                      Bulletproof 2
# 16                                 Sonic the Hedgehog
# 17                           Las Pildoras de mi Novio
# 18                       Hasta que la boda nos separe
# 19                                          ヲタクに恋は難しい
#
#                                              overview  popularity  \
# 0   Harley Quinn joins forces with a singer, an as...     558.568
# 1   Marcus and Mike are forced to confront new thr...     467.754
# 2   In 2006, a group of thieves performed what is ...     388.673
# 3   Lukas, a young farmer whose family is killed b...     352.099
# 4   During the last years of Pinochet's military r...     325.648
# 5   When a billionaire gives a group of young scie...     319.174
# 6   After an earthquake destroys their underwater ...     227.394
# 7   In 1934, Bolivia is at war with Paraguay. Libo...     225.488
# 8   The young family who moved to a new apartment ...     212.264
# 9   At the turning point of the Iran-Contra affair...     192.931
# 10  A hotel room shootout between two assassins ki...     178.108
# 11  Blake Lively stars as Stephanie Patrick, a wom...     173.180
# 12  A group of young Miskatonic University scienti...     172.216
# 13  Goblin Slayer and his party head up to the sno...     167.927
# 14  Four young men who want to leave their dystopi...     167.700
# 15  Special Agent Jack Carter reluctantly assumes ...     122.294
# 16  Based on the global blockbuster videogame fran...     117.176
# 17  A Woman's island getaway with her boyfriend is...     107.298
# 18  Marina is a woman in her thirties who works or...      95.479
# 19  An effervescent musical about one of the most ...      89.222
#
#                          poster_path release_date  \
# 0   /h4VB6m0RwcicVEZvzftYZyKXs6K.jpg   2020-02-05
# 1   /y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg   2020-01-15
# 2   /aSGwXbaTMxUhrfXT6xyZKqoklfB.jpg   2020-01-16
# 3   /qs6gz6atyQcAvqC6qZaslOjliUG.jpg   2020-02-04
# 4   /qDFfu73R8uO94ydFtdxEdSfTlg6.jpg   2020-01-23
# 5   /8jDvtdH327I8TgX3UPdkAsZF1dA.jpg   2020-01-24
# 6   /gzlbb3yeVISpQ3REd3Ga1scWGTU.jpg   2020-01-08
# 7   /hCR2i9rK6P4VHMfFw2MT5jDGJcN.jpg   2020-01-28
# 8   /8m5HTXzwewlfXhtZtLlLts53YTW.jpg   2020-02-27
# 9    /gItrnbEbMBbUrdIkFz8kgS2gkt.jpg   2020-02-14
# 10  /wy0Xs5mGtD92PyKvsl0lxzbzscG.jpg   2020-02-20
# 11  /spTr0VYyRtl36Lkk6nCnnbFXhus.jpg   2020-01-31
# 12  /e6hgmD0P133bW5EH1kfhscwXN2a.jpg   2020-02-12
# 13  /oyDaF4za9C9GxfYSyZUmj2aZGJT.jpg   2020-02-01
# 14  /bkuuvDoPkOJpg0ZDzHkUWt8ZG5A.jpg   2020-02-22
# 15  /uGILkFnRrpdiNtDaHeekGZSn5o5.jpg   2020-01-07
# 16  /aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg   2020-02-12
# 17  /hVSOXCBuPXw8yXqbNfwU9ogIp88.jpg   2020-02-14
# 18   /bkz7ZoqJMFziqF8yQzkmfMRUEG.jpg   2020-02-14
# 19  /9JV0LOcazudqEcz2NNOMqEIzACz.jpg   2020-02-07
#
#                                                 title  video  vote_average  \
# 0   Birds of Prey (and the Fantabulous Emancipatio...  False           7.1
# 1                                   Bad Boys for Life  False           7.2
# 2                            The Heist of the Century  False           8.0
# 3                              Dragonheart: Vengeance  False           6.9
# 4                                       Pacto de Fuga  False           7.8
# 5                                    Assassin 33 A.D.  False           5.2
# 6                                          Underwater  False           6.3
# 7                                               Chaco  False           7.9
# 8                Baba Yaga: Terror of the Dark Forest  False           6.2
# 9                            The Last Thing He Wanted  False           5.0
# 10                                         Kill Chain  False           5.6
# 11                                 The Rhythm Section  False           5.6
# 12                                          Intersect  False           6.0
# 13                      Goblin Slayer: Goblin's Crown  False           7.8
# 14                                       Time to Hunt  False           7.3
# 15                                      Bulletproof 2  False           7.1
# 16                                 Sonic the Hedgehog  False           7.5
# 17                                My Boyfriend's Meds  False           7.2
# 18                              The Wedding Unplanner  False           6.9
# 19                    Wotakoi: Love is Hard for Otaku  False           7.1
#
#     vote_count
# 0         7334
# 1         6170
# 2          481
# 3          212
# 4           55
# 5           58
# 6         2014
# 7           40
# 8          117
# 9          323
# 10          68
# 11         353
# 12          32
# 13         107
# 14         173
# 15          72
# 16        6737
# 17         268
# 18         104
# 19          34

# %% [markdown]
# ##  Importing and Saving the Movies Dataset (Best Practice)

# %% [markdown]
# 6. __API-Request__ (movie module): Load all available information for the movies with movie id = [__299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513__] into a Pandas DataFrame and __save the dataset in a local json file__.

# %%
movieIDs = [299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513]
jsonList = []
baseURL = 'https://api.themoviedb.org/3/movie/{}?api_key={}&language=en-US'
for movie in movieIDs:
    url = baseURL.format(movie, apiKey)
    req = requests.get(url)
    if req.status_code != 200:
        continue
    else:
        data = req.json()
        jsonList.append(data)
        
df = pd.DataFrame(jsonList)
df.to_json('movies.json', orient='records')

data = json.load(open('movies.json'))
df = pd.json_normalize(data)
df.head()
# Out:
#    adult                     backdrop_path     budget  \
# 0  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg  356000000
# 1  False  /AmHOQ7rpHwiaUMRjKXztnauSJb7.jpg  237000000
# 2  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg  245000000
# 3  False  /lmZFxXgJE3vgrciwuDib0N8CfQo.jpg  300000000
# 4  False  /6VmFqApQRyZZzmiGOQq2C92jyvH.jpg  200000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                             homepage      id    imdb_id  \
# 0     https://www.marvel.com/movies/avengers-endgame  299534  tt4154796
# 1                        http://www.avatarmovie.com/   19995  tt0499549
# 2  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 3  https://www.marvel.com/movies/avengers-infinit...  299536  tt4154756
# 4                                                        597  tt0120338
#
#   original_language                original_title  \
# 0                en             Avengers: Endgame
# 1                en                        Avatar
# 2                en  Star Wars: The Force Awakens
# 3                en        Avengers: Infinity War
# 4                en                       Titanic
#
#                                             overview  ...  \
# 0  After the devastating events of Avengers: Infi...  ...
# 1  In the 22nd century, a paraplegic Marine is di...  ...
# 2  Thirty years after defeating the Galactic Empi...  ...
# 3  As the Avengers and their allies have continue...  ...
# 4  101-year-old Rose DeWitt Bukater tells the sto...  ...
#
#                                      tagline                         title  \
# 0            Part of the journey is the end.             Avengers: Endgame
# 1                Enter the World of Pandora.                        Avatar
# 2              Every generation has a story.  Star Wars: The Force Awakens
# 3      An entire universe. Once and for all.        Avengers: Infinity War
# 4  Nothing on Earth could come between them.                       Titanic
#
#    video vote_average vote_count  belongs_to_collection.id  \
# 0  False          8.3      17838                   86311.0
# 1  False          7.5      23201                   87096.0
# 2  False          7.4      15688                      10.0
# 3  False          8.3      21519                   86311.0
# 4  False          7.9      19003                       NaN
#
#    belongs_to_collection.name belongs_to_collection.poster_path  \
# 0     The Avengers Collection  /yQpAleQ1KHebVem2vwWL6VPqILT.jpg
# 1           Avatar Collection  /gC3tW9a45RGOzzSh6wv91pFnmFr.jpg
# 2        Star Wars Collection  /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg
# 3     The Avengers Collection  /yQpAleQ1KHebVem2vwWL6VPqILT.jpg
# 4                         NaN                               NaN
#
#   belongs_to_collection.backdrop_path belongs_to_collection
# 0    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg                   NaN
# 1    /syGPZuzcHBBHMLiNDN0x0Tms4Fk.jpg                   NaN
# 2    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg                   NaN
# 3    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg                   NaN
# 4                                 NaN                   NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# # +++++++++ See some Hints below +++++++++++++

# %% [markdown]
# # ++++++++++++++ Hints +++++++++++++++++++++

# %% [markdown]
# __Hints for 1.__ <br>
# To load json files you can use

# %%
with open("filename.json") as f:
    data = json.load(f)

# %% [markdown]
# and

# %%
pd.DataFrame(data), pd.read_json(filename.json), pd.json_normalize(data)

# %% [markdown]
# the json files have the following orientation (important when using pd.read_json()):
# - blockbusters.json -> record
# - blockbusters2.json -> column
# - blockbusters3.json -> split

# %% [markdown]
# __Hints for 4., 5., 6.__<br>
# Make API GET-requests with the library requests (import requests):

# %%
data = requests.get(url).json()

# %% [markdown]
# __Hints for 4. and 6.,__ <br> url structure for movie module:

# %% [markdown]
# "https://api.themoviedb.org/3/movie/insert_movie_id?api_key=insert_api_key" (replace "insert_movie_id" with movie id and "insert_api_key" with your personal api-key)

# %% [markdown]
# __Hints for 5.__<br>
# url structure for discover module:

# %% [markdown]
# "https://api.themoviedb.org/3/discover/movie?api_key=insert_api_key&query1&query2..." (replace "insert_api_key" with your personal api-key and add appropriate queries)
